-- %% [markdown]
-- # Validaciones

-- %% [markdown]
-- ## Bronze

-- %%
SELECT * FROM electrocasa.bronze.ventas_bronze

-- %%
SELECT count(*) FROM electrocasa.bronze.ventas_bronze -- 15 225

-- %%
SELECT * FROM electrocasa.bronze.productos_bronze

-- %%
SELECT count(*) FROM electrocasa.bronze.productos_bronze -- 3 095

-- %%
SELECT * FROM electrocasa.bronze.devoluciones_bronze

-- %%
SELECT count(*) FROM electrocasa.bronze.devoluciones_bronze -- 4 040

-- %%
SELECT * FROM electrocasa.bronze.empleados_bronze

-- %%
SELECT count(*) FROM electrocasa.bronze.empleados_bronze -- 4 078

-- %%
SELECT * FROM electrocasa.bronze.resenas_bronze

-- %%
SELECT count(*) FROM electrocasa.bronze.resenas_bronze -- 8 080

-- %% [markdown]
-- ## Silver

-- %%
SELECT * FROM electrocasa.silver.ventas_silver

-- %%
SELECT count(*) FROM electrocasa.silver.ventas_silver -- 15 000

-- %%
SELECT * FROM electrocasa.silver.productos_silver

-- %%
SELECT count(*) FROM electrocasa.silver.productos_silver -- 3 000

-- %%
SELECT * FROM electrocasa.silver.devoluciones_silver

-- %%
SELECT count(*) FROM electrocasa.silver.devoluciones_silver -- 4 000

-- %%
SELECT * FROM electrocasa.silver.empleados_silver

-- %%
SELECT count(*) FROM electrocasa.silver.empleados_silver -- 4 076

-- %%
SELECT * FROM electrocasa.silver.resenas_silver

-- %%
SELECT count(*) FROM electrocasa.silver.resenas_silver -- 8 000

-- %% [markdown]
-- ## Gold

-- %%
SELECT * FROM electrocasa.gold.dotacion_sucursal;

-- %%
SELECT * FROM electrocasa.gold.ranking_productos;

-- %%
SELECT * FROM electrocasa.gold.resenas_categoria;

-- %%
SELECT * FROM electrocasa.gold.ventas_sucursal_mes;

-- %%
SELECT * FROM electrocasa.gold.tracking_envios
