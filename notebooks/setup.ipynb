# %%
# %sql

CREATE CATALOG IF NOT EXISTS electrocasa;
CREATE SCHEMA IF NOT EXISTS electrocasa.bronze;
CREATE SCHEMA IF NOT EXISTS electrocasa.silver;
CREATE SCHEMA IF NOT EXISTS electrocasa.gold;

CREATE VOLUME IF NOT EXISTS electrocasa.bronze.landing;

# %%
# %sql
GRANT USE CATALOG ON CATALOG mi_catalogo TO `nombre_del_grupo`;
GRANT USE SCHEMA ON SCHEMA mi_catalogo.mi_esquema TO `nombre_del_grupo`;
GRANT SELECT ON TABLE mi_catalogo.mi_esquema.mi_tabla TO `nombre_del_grupo`;

# %%
# %sql
REVOKE SELECT ON TABLE mi_catalogo.mi_esquema.mi_tabla FROM `nombre_del_grupo`;
